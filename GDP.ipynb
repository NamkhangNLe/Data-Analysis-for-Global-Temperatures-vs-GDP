# %%
import pandas as pd

df1 = pd.read_csv("GDP_annual_growth.csv", index_col = ['Country Name'])
df1
df1 = df1.drop(['Unnamed: 65', 'Country Code', 'Indicator Code', 'Indicator Name', '2014', '2015', '2016', '2017', '2018', '2019', '2020'], axis=1)
df1
# Out:
#                       1960          1961          1962          1963  \
# Country Name
# Aruba                  NaN           NaN           NaN           NaN
# Afghanistan   5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# Angola                 NaN           NaN           NaN           NaN
# Albania                NaN           NaN           NaN           NaN
# Andorra                NaN           NaN           NaN           NaN
# ...                    ...           ...           ...           ...
# Kosovo                 NaN           NaN           NaN           NaN
# Yemen, Rep.            NaN           NaN           NaN           NaN
# South Africa  7.575397e+09  7.972997e+09  8.497997e+09  9.423396e+09
# Zambia        7.130000e+08  6.962857e+08  6.931429e+08  7.187143e+08
# Zimbabwe      1.052990e+09  1.096647e+09  1.117602e+09  1.159512e+09
#
#                       1964          1965          1966          1967  \
# Country Name
# ...

# %%
df1 = df1.loc[['Honduras', 'Haiti','Afghanistan','Philippines','China', 'United States', 'Japan', 'United Kingdom']]
df1
# Out:
#                         1960          1961          1962          1963  \
# Country Name
# Honduras        3.356500e+08  3.562000e+08  3.877500e+08  4.102000e+08
# Haiti           2.731872e+08  2.710660e+08  2.818968e+08  2.948834e+08
# Afghanistan     5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# Philippines     6.684569e+09  7.256967e+09  4.399828e+09  4.875310e+09
# China           5.971647e+10  5.005687e+10  4.720936e+10  5.070680e+10
# United States   5.433000e+11  5.633000e+11  6.051000e+11  6.386000e+11
# Japan           4.430734e+10  5.350862e+10  6.072302e+10  6.949813e+10
# United Kingdom  7.323397e+10  7.774197e+10  8.124756e+10  8.656196e+10
#
#                         1964          1965          1966          1967  \
# Country Name
# Honduras        4.570000e+08  5.086500e+08  5.499500e+08  5.981000e+08
# Haiti           3.252812e+08  3.532518e+08  3.689486e+08  3.691242e+08
# Afghanistan     8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09
# ...

# %%
#Export
df1 = df1.to_csv('/Users/Explo1t/Documents/Nueda/completedGDP.csv', index = True)
