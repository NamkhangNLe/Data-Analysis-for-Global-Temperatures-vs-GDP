# %%
#Import pandas
import pandas as pd
import numpy as np

# %%
#Reads in CSV File and removes unnecessary rows
df1 = pd.read_csv("completedTemperature.csv", index_col = ['dt'], usecols=['dt', 'AverageTemperature', 'Country'])
df1

df1['GDP'] = np.nan
df1
# Out:
#             AverageTemperature   Country  GDP
# dt
# 1960-08-01              18.978     China  NaN
# 1961-08-01              18.952     China  NaN
# 1962-08-01              18.881     China  NaN
# 1963-08-01              19.229     China  NaN
# 1964-08-01              19.021     China  NaN
# ...                        ...       ...  ...
# 2009-08-01              18.465  Zimbabwe  NaN
# 2010-08-01              18.260  Zimbabwe  NaN
# 2011-08-01              17.883  Zimbabwe  NaN
# 2012-08-01              18.946  Zimbabwe  NaN
# 2013-08-01              19.759  Zimbabwe  NaN
#
# [432 rows x 3 columns]

# %%
df2 = pd.read_csv("completedGDP.csv", index_col = ['Country Name'])
df2 = df2.T
df2

# df2.index = pd.to_datetime(df2.index)
# df2
# Out:
# Country Name      Honduras         Haiti      Zimbabwe   Philippines  \
# 1960          3.356500e+08  2.731872e+08  1.052990e+09  6.684569e+09
# 1961          3.562000e+08  2.710660e+08  1.096647e+09  7.256967e+09
# 1962          3.877500e+08  2.818968e+08  1.117602e+09  4.399828e+09
# 1963          4.102000e+08  2.948834e+08  1.159512e+09  4.875310e+09
# 1964          4.570000e+08  3.252812e+08  1.217138e+09  5.271405e+09
# 1965          5.086500e+08  3.532518e+08  1.311436e+09  5.784399e+09
# 1966          5.499500e+08  3.689486e+08  1.281750e+09  6.371459e+09
# 1967          5.981000e+08  3.691242e+08  1.397002e+09  6.809134e+09
# 1968          6.468000e+08  3.679688e+08  1.479600e+09  7.591603e+09
# 1969          6.680000e+08  3.918204e+08  1.747999e+09  8.408230e+09
# 1970          7.230000e+08  3.312000e+08  1.884206e+09  6.687205e+09
# 1971          7.310000e+08  3.628000e+08  2.178716e+09  7.408306e+09
# 1972          8.030000e+08  3.720000e+08  2.677729e+09  8.017469e+09
# ...

# %%
# df1.loc['1960':'2013' & df1['Country'] == 'China'] = df2.loc['1960':'2013' & df2['Country Name'] == 'China']
list1 = df2['China'].tolist()
list1.extend(df2['Haiti'].tolist())
list1.extend(df2['Honduras'].tolist())
list1.extend(df2['Japan'].tolist())
list1.extend(df2['Philippines'].tolist())
list1.extend(df2['United Kingdom'].tolist())
list1.extend(df2['United States'].tolist())
list1.extend(df2['Zimbabwe'].tolist())
list1

df1['GDP'] = list1
df1
# Out:
#             AverageTemperature   Country           GDP
# dt
# 1960-08-01              18.978     China  5.971647e+10
# 1961-08-01              18.952     China  5.005687e+10
# 1962-08-01              18.881     China  4.720936e+10
# 1963-08-01              19.229     China  5.070680e+10
# 1964-08-01              19.021     China  5.970834e+10
# ...                        ...       ...           ...
# 2009-08-01              18.465  Zimbabwe  9.665793e+09
# 2010-08-01              18.260  Zimbabwe  1.204166e+10
# 2011-08-01              17.883  Zimbabwe  1.410192e+10
# 2012-08-01              18.946  Zimbabwe  1.711485e+10
# 2013-08-01              19.759  Zimbabwe  1.909102e+10
#
# [432 rows x 3 columns]

# %%
df1 = df1.to_csv('combine.csv', index = True)
